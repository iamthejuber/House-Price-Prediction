# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# %%
file_path = "C:\\Users\\JUBER PATHAN\\Data Science\\kc_house_data.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
visa_df.head(7) # head means first five value
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# ...

# %%
visa_df.tail(7)  #tail mean last five value
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# ...

# %%
# chechking the number of rows and columns in the data
visa_df.shape
# Out:
# (21613, 21)

# %%
# To get the column names in the data
visa_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#To get the datatype of every column from the data
visa_df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
visa_df.select_dtypes('int64')
# Out:
#                id  bedrooms  sqft_living  sqft_lot  waterfront  view  \
# 0      7129300520         3         1180      5650           0     0
# 1      6414100192         3         2570      7242           0     0
# 2      5631500400         2          770     10000           0     0
# 3      2487200875         4         1960      5000           0     0
# 4      1954400510         3         1680      8080           0     0
# ...           ...       ...          ...       ...         ...   ...
# 21608   263000018         3         1530      1131           0     0
# 21609  6600060120         4         2310      5813           0     0
# 21610  1523300141         2         1020      1350           0     0
# 21611   291310100         3         1600      2388           0     0
# 21612  1523300157         2         1020      1076           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
visa_df.select_dtypes('object')
# Out:
#                   date
# 0      20141013T000000
# 1      20141209T000000
# 2      20150225T000000
# 3      20141209T000000
# 4      20150218T000000
# ...                ...
# 21608  20140521T000000
# 21609  20150223T000000
# 21610  20140623T000000
# 21611  20150116T000000
# 21612  20141015T000000
#
# [21613 rows x 1 columns]

# %%
# To check the missing values 
visa_df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
visa_df.isnull().values.any()
# Out:
# False

# %%
# statistical measures of the dataset
visa_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
bed_room=visa_df['bedrooms']
bed_room
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
bed_room.value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
bed_room_mean=round(np.mean(visa_df['bedrooms']),2)
bed_room_median=round(np.median(visa_df['bedrooms']),2)
bed_room_min=round(np.min(visa_df['bedrooms']),2)
bed_room_max=round(np.max(visa_df['bedrooms']),2)
bed_room_std=round(np.std(visa_df['bedrooms']),2)

list1=[bed_room_mean,bed_room_median,bed_room_min,bed_room_max,bed_room_std]
index=['Mean','Median','Min','Max','Std']
pd.DataFrame(list1,columns=['bedrooms'],index=index)
# Out:
#         bedrooms
# Mean        3.37
# Median      3.00
# Min         0.00
# Max        33.00
# Std         0.93

# %%
visa_df.describe(include='all').T
# Out:
#                  count unique              top freq               mean  \
# id             21613.0    NaN              NaN  NaN  4580301520.864988
# date             21613    372  20140623T000000  142                NaN
# price          21613.0    NaN              NaN  NaN      540088.141767
# bedrooms       21613.0    NaN              NaN  NaN           3.370842
# bathrooms      21613.0    NaN              NaN  NaN           2.114757
# sqft_living    21613.0    NaN              NaN  NaN        2079.899736
# sqft_lot       21613.0    NaN              NaN  NaN       15106.967566
# floors         21613.0    NaN              NaN  NaN           1.494309
# waterfront     21613.0    NaN              NaN  NaN           0.007542
# view           21613.0    NaN              NaN  NaN           0.234303
# condition      21613.0    NaN              NaN  NaN            3.40943
# grade          21613.0    NaN              NaN  NaN           7.656873
# ...

# %%
visa_df.hist(bins=50,figsize=(15,15))
plt.show()

# %%
visa_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.boxplot(data=visa_df,x=visa_df['bathrooms'],y=visa_df['price'])
plt.show()

# %%
sns.countplot(data=visa_df,x=visa_df['bathrooms'])
plt.show()

# %%
sns.regplot(data=visa_df,x=visa_df['sqft_above'],y=visa_df['price'])
plt.show()

# %%
visa_df1 = visa_df.drop(columns= 'date',inplace = True)
visa_df1

# %%
visa_df
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
corr_matrix = visa_df.corr()
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu");
bottom,top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
sns.heatmap(visa_df)
plt.show()
